# %%
import os
import sys
import pandas as pd
from tqdm import tqdm
from astropy.io import fits
import operator
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import matplotlib
import subprocess
from collections import Counter

# %%
# %%bash
#
# cd /home/jen55/urry2023/jen55/DRAGON_CNN && PYTHONPATH=$(pwd) ; export PYTHONPATH && pwd
# Out:
# /home/jen55/urry2023/jen55/DRAGON_CNN

# %%
os.chdir("/home/jen55/palmer_scratch/DRAGON_CNN_NEW/DRAGON_CNN")
os.environ["PYTHONPATH"] = os.getcwd()

# %%
path = Path('good_models/voters')
model_paths = [fl.as_posix() for fl in path.glob('*.pt')]
model_stems = [fl.stem for fl in path.glob('*.pt')]

# %%
# Locate good models
output_paths = ['tang_candidates/', 'merger_test/']
data_dirs = ['tang_candidates', 'merger_test']

# Loop over the parameters
for output_path, data_dir in zip(output_paths, data_dirs):
    for model_path, model_stem in zip(model_paths, model_stems):
        command = [
            'python', 'modules/inference.py',
            '--model_path', model_path,
            '--model_type', 'dragon',
            '--output_path', (output_path + model_stem),
            '--data_dir', data_dir,
            '--slug', 'balanced-dev',
            '--n_workers', "4",
            '--parallel',
            '--batch_size', "32",
            '--label_col', 'classes',
            '--n_classes', "6",
            '--normalize',
            '--dropout_rate', "0.0004",
            '--cutout_size', "94",
            '--channels', "1"
        ]

        # Remove empty arguments
        command = [arg for arg in command if arg]
        print(command)

        # Run the command
        subprocess.run(command)
# Out:
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/fixed_hp-balanced-dev-bbynd7iu.pt', '--model_type', 'dragon', '--output_path', 'tang_candidates/fixed_hp-balanced-dev-bbynd7iu', '--data_dir', 'tang_candidates', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 10:48:20,389] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 10:48:20,407] Loading images to device...
# [2024-07-22 10:48:20,443] Using 1 GPUs.
# [2024-07-22 10:48:20,446] Generating PyTorch tensors from FITS files...
# 100%|██████████| 32/32 [00:00<00:00, 67446.09it/s]
# [2024-07-22 10:48:20,451] Preloading PyTorch tensors before transfer...
# 100%|██████████| 32/32 [00:00<00:00, 740.79it/s]
# [2024-07-22 10:48:20,566] Initialization of FITS Dataset Completed.
# [2024-07-22 10:48:20,566] Running inference run 1
# [2024-07-22 10:48:20,566] Using 1 GPUs.
# [2024-07-22 10:48:22,406] Loading model...
# [2024-07-22 10:48:22,463] Performing predictions...
# [2024-07-22 10:48:22,463] Activating Monte Carlo dropout...
# 100%|██████████| 1/1 [00:02<00:00,  2.43s/it]
# [2024-07-22 10:48:24,912] Catalog saved to tang_candidates/fixed_hp-balanced-dev-bbynd7iuinf_1.csv
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/many_models-balanced-dev-0fbt70pr.pt', '--model_type', 'dragon', '--output_path', 'tang_candidates/many_models-balanced-dev-0fbt70pr', '--data_dir', 'tang_candidates', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 10:48:27,724] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 10:48:27,737] Loading images to device...
# [2024-07-22 10:48:27,782] Using 1 GPUs.
# [2024-07-22 10:48:27,785] Generating PyTorch tensors from FITS files...
# 100%|██████████| 32/32 [00:00<00:00, 2659.83it/s]
# [2024-07-22 10:48:27,807] Preloading PyTorch tensors before transfer...
# 100%|██████████| 32/32 [00:00<00:00, 537.41it/s]
# [2024-07-22 10:48:27,941] Initialization of FITS Dataset Completed.
# [2024-07-22 10:48:27,941] Running inference run 1
# [2024-07-22 10:48:27,941] Using 1 GPUs.
# [2024-07-22 10:48:28,929] Loading model...
# [2024-07-22 10:48:28,965] Performing predictions...
# [2024-07-22 10:48:28,965] Activating Monte Carlo dropout...
# 100%|██████████| 1/1 [00:02<00:00,  2.27s/it]
# [2024-07-22 10:48:31,247] Catalog saved to tang_candidates/many_models-balanced-dev-0fbt70prinf_1.csv
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/many_models-balanced-dev-jxvydzs2.pt', '--model_type', 'dragon', '--output_path', 'tang_candidates/many_models-balanced-dev-jxvydzs2', '--data_dir', 'tang_candidates', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 10:48:34,172] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 10:48:34,188] Loading images to device...
# [2024-07-22 10:48:34,283] Using 1 GPUs.
# [2024-07-22 10:48:34,290] Generating PyTorch tensors from FITS files...
# 100%|██████████| 32/32 [00:00<00:00, 61965.71it/s]
# [2024-07-22 10:48:34,303] Preloading PyTorch tensors before transfer...
# 100%|██████████| 32/32 [00:00<00:00, 683.39it/s]
# [2024-07-22 10:48:34,434] Initialization of FITS Dataset Completed.
# [2024-07-22 10:48:34,434] Running inference run 1
# [2024-07-22 10:48:34,434] Using 1 GPUs.
# [2024-07-22 10:48:35,528] Loading model...
# [2024-07-22 10:48:35,818] Performing predictions...
# [2024-07-22 10:48:35,819] Activating Monte Carlo dropout...
# 100%|██████████| 1/1 [00:02<00:00,  2.26s/it]
# [2024-07-22 10:48:38,084] Catalog saved to tang_candidates/many_models-balanced-dev-jxvydzs2inf_1.csv
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/fixed_hp-balanced-dev-bbynd7iu.pt', '--model_type', 'dragon', '--output_path', 'merger_test/fixed_hp-balanced-dev-bbynd7iu', '--data_dir', 'merger_test', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 10:48:40,757] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 10:48:40,778] Loading images to device...
# [2024-07-22 10:48:40,830] Using 1 GPUs.
# [2024-07-22 10:48:40,855] Generating PyTorch tensors from FITS files...
# 100%|██████████| 12708/12708 [00:12<00:00, 1038.98it/s]
# [2024-07-22 10:48:53,126] Preloading PyTorch tensors before transfer...
# 100%|██████████| 12708/12708 [00:26<00:00, 471.22it/s]
# [2024-07-22 10:49:20,184] Initialization of FITS Dataset Completed.
# [2024-07-22 10:49:20,185] Running inference run 1
# [2024-07-22 10:49:20,185] Using 1 GPUs.
# [2024-07-22 10:49:21,299] Loading model...
# [2024-07-22 10:49:21,329] Performing predictions...
# [2024-07-22 10:49:21,330] Activating Monte Carlo dropout...
# 100%|██████████| 398/398 [00:09<00:00, 42.30it/s]
# [2024-07-22 10:49:30,802] Catalog saved to merger_test/fixed_hp-balanced-dev-bbynd7iuinf_1.csv
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/many_models-balanced-dev-0fbt70pr.pt', '--model_type', 'dragon', '--output_path', 'merger_test/many_models-balanced-dev-0fbt70pr', '--data_dir', 'merger_test', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 10:49:34,743] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 10:49:34,760] Loading images to device...
# [2024-07-22 10:49:34,821] Using 1 GPUs.
# [2024-07-22 10:49:34,846] Generating PyTorch tensors from FITS files...
# 100%|██████████| 12708/12708 [00:00<00:00, 118079.26it/s]
# [2024-07-22 10:49:34,986] Preloading PyTorch tensors before transfer...
# 100%|██████████| 12708/12708 [00:27<00:00, 463.41it/s]
# [2024-07-22 10:50:02,594] Initialization of FITS Dataset Completed.
# [2024-07-22 10:50:02,594] Running inference run 1
# [2024-07-22 10:50:02,594] Using 1 GPUs.
# [2024-07-22 10:50:03,722] Loading model...
# [2024-07-22 10:50:03,775] Performing predictions...
# [2024-07-22 10:50:03,775] Activating Monte Carlo dropout...
# 100%|██████████| 398/398 [00:09<00:00, 43.84it/s]
# [2024-07-22 10:50:12,879] Catalog saved to merger_test/many_models-balanced-dev-0fbt70prinf_1.csv
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/many_models-balanced-dev-jxvydzs2.pt', '--model_type', 'dragon', '--output_path', 'merger_test/many_models-balanced-dev-jxvydzs2', '--data_dir', 'merger_test', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 10:50:16,232] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 10:50:16,246] Loading images to device...
# [2024-07-22 10:50:16,283] Using 1 GPUs.
# [2024-07-22 10:50:16,308] Generating PyTorch tensors from FITS files...
# 100%|██████████| 12708/12708 [00:00<00:00, 134034.46it/s]
# [2024-07-22 10:50:16,414] Preloading PyTorch tensors before transfer...
# 100%|██████████| 12708/12708 [00:23<00:00, 550.65it/s]
# [2024-07-22 10:50:39,657] Initialization of FITS Dataset Completed.
# [2024-07-22 10:50:39,658] Running inference run 1
# [2024-07-22 10:50:39,658] Using 1 GPUs.
# [2024-07-22 10:50:40,580] Loading model...
# [2024-07-22 10:50:40,620] Performing predictions...
# [2024-07-22 10:50:40,620] Activating Monte Carlo dropout...
# 100%|██████████| 398/398 [00:08<00:00, 47.91it/s]
# [2024-07-22 10:50:48,958] Catalog saved to merger_test/many_models-balanced-dev-jxvydzs2inf_1.csv

# %%
# Creation of majority CSV
for output_path, data_dir in zip(output_paths, data_dirs):
    path = Path(output_path)
    df = pd.DataFrame()  # Initialize an empty DataFrame
    
    index = 0
    for csv in path.glob('*inf_1.csv'):
        ndf = pd.read_csv(csv)

        # Append file names if not already present
        if "file_name" not in df.columns:
            df["file_name"] = ndf["file_name"]
        
        # Add predicted labels as new columns
        voter_column = f"voter_{index}"
        voter_confidence = f"voter_{index}_conf"
        
        df[voter_column] = ndf["predicted_labels"]
        df[voter_confidence] = ndf["predicted_confidence"]
        
        index += 1

    # Combined results
    df.to_csv(path / 'combined_results.csv', index=False)

# %%
def congress(path, csv='combined_results.csv'):
    df = pd.read_csv(path + '/combined_results.csv')
    
    congress = pd.DataFrame(columns=["file_name", "voted_class", "num_voters", "total_voters", "confidence"])

    num_voters = 0
    for header in df.columns:
        if "voter" in header and not "conf" in header:
            num_voters += 1
    
    # First round voting
    labels = np.unique(df["voter_0"])        
    for _, row in df.iterrows():
        voter_vals = Counter([row[f"voter_{index}"] for index in range(num_voters)])
        confidence_vals = [row[f"voter_{index}_conf"] for index in range(num_voters)]
        majority, maj_count = voter_vals.most_common(1)[0]
        
        voted_class = majority
        
        # If there is another one
        if len(voter_vals) > 1:
            second, second_count = voter_vals.most_common(2)[1]
            if maj_count - 1 <= second_count <= maj_count:
                voted_class = -1
        
        avg_confidence = sum(confidence_vals) / len(confidence_vals)
        
        congress.loc[len(congress)] = {
            "file_name": row["file_name"], 
            "voted_class": voted_class,
            "num_voters": maj_count,
            "total_voters": num_voters,
            "confidence": avg_confidence
        }
        
    print(congress)
    congress.to_csv(path + '/congress.csv')
    
for data_dir in data_dirs:
    congress(data_dir)
# Out:
#                   file_name voted_class num_voters total_voters  confidence
# 0   000439.97-000146.4.fits           2          4            4    0.529002
# 1   000508.37+010806.4.fits           5          4            4    0.974581
# 2   000837.66-010313.7.fits           5          4            4    0.964699
# 3   011935.29-002033.5.fits           2          4            4    0.742292
# 4   012716.17-003557.6.fits           3          4            4    0.733753
# 5   020318.87-062321.3.fits           5          4            4    0.983268
# 6   021352.67-021129.4.fits           5          3            4    0.525792
# 7   021930.51-055643.0.fits           4          4            4    0.794404
# 8   022105.64-044101.5.fits           4          4            4    0.976538
# 9   022159.71-014512.0.fits           5          4            4    0.625687
# 10  084710.40-001302.6.fits           5          4            4    0.924296
# 11  084856.08+011540.0.fits           5          4            4    0.954356
# 12  090347.33+002026.2.fits           5          4            4    0.685979
# 13  094132.90+000731.1.fits           2          3            4    0.499976
# 14  121405.12+010205.1.fits           5          4            4    0.960510
# 15  123821.66+010518.6.fits           5          4            4    0.843974
# 16  141637.44+003352.2.fits           5          4            4    0.919106
# 17  220228.65+004901.9.fits           5          4            4    0.963934
# 18  220501.19+003122.8.fits           5          4            4    0.920724
# 19  220718.43-001723.1.fits           5          4            4    0.546188
# 20  220811.56+023830.1.fits           5          4            4    0.982075
# 21  220906.91+004543.9.fits           5          4            4    0.946784
# 22  221115.06-000030.9.fits           5          4            4    0.788062
# 23  221227.74+005140.5.fits           5          4            4    0.948250
# 24  221759.58+060426.3.fits           5          4            4    0.834350
# 25  222057.44+000329.8.fits           5          4            4    0.937237
# 26  222929.45+010438.4.fits           5          4            4    0.929254
# 27  225147.82+001640.5.fits           5          4            4    0.849397
# 28  230322.74-001438.2.fits           5          4            4    0.917852
# 29  231152.90-001335.0.fits           2          3            4    0.756602
# 30  232853.40+011221.8.fits           4          3            4    0.543167
# 31  233713.66+005610.8.fits           5          4            4    0.972091
#                                                file_name voted_class  \
# 0      mergerAGN_test/hsc_2626_test_HSC-G/QSO_220401_...           2
# 1      mergerAGN_test/hsc_2626_test_HSC-G/QSO_220401_...           2
# 2      mergerAGN_test/hsc_2626_test_HSC-G/QSO_220402_...           5
# 3      mergerAGN_test/hsc_2626_test_HSC-G/QSO_220402_...          -1
# 4      mergerAGN_test/hsc_2626_test_HSC-G/QSO_220402_...          -1
# ...                                                  ...         ...
# 12703  mergerAGN_test/train_data/9995-cutout-HSC-G-10...           4
# 12704  mergerAGN_test/train_data/9996-cutout-HSC-G-10...           4
# 12705  mergerAGN_test/train_data/9997-cutout-HSC-G-10...           4
# 12706  mergerAGN_test/train_data/9998-cutout-HSC-G-10...           4
# 12707  mergerAGN_test/train_data/9999-cutout-HSC-G-10...           4
#
#       num_voters total_voters  confidence
# 0              4            5    0.749945
# 1              4            5    0.848229
# 2              4            5    0.894758
# 3              2            5    0.674006
# 4              2            5    0.658891
# ...          ...          ...         ...
# 12703          4            5         NaN
# 12704          4            5         NaN
# 12705          4            5         NaN
# 12706          4            5         NaN
# 12707          4            5         NaN
#
# [12708 rows x 5 columns]

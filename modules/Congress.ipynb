# %%
import os
import sys
import pandas as pd
from tqdm import tqdm
from astropy.io import fits
import operator
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import matplotlib
import subprocess
from collections import Counter

# %%
# %%bash
#
# cd /home/jen55/urry2023/jen55/DRAGON_CNN && PYTHONPATH=$(pwd) ; export PYTHONPATH && pwd
# Out:
# /home/jen55/urry2023/jen55/DRAGON_CNN

# %%
os.chdir("/home/jen55/palmer_scratch/DRAGON_CNN_NEW/DRAGON_CNN")
os.environ["PYTHONPATH"] = os.getcwd()

# %%
path = Path('good_models/voters')
model_paths = [fl.as_posix() for fl in path.glob('*.pt')]
model_stems = [fl.stem for fl in path.glob('*.pt')]

# %%
# Locate good models
output_paths = ['tang_candidates/', 'merger_test/']
data_dirs = ['tang_candidates', 'merger_test']

# Loop over the parameters
for output_path, data_dir in zip(output_paths, data_dirs):
    for model_path, model_stem in zip(model_paths, model_stems):
        command = [
            'python', 'modules/inference.py',
            '--model_path', model_path,
            '--model_type', 'dragon',
            '--output_path', (output_path + model_stem),
            '--data_dir', data_dir,
            '--slug', 'balanced-dev',
            '--n_workers', "4",
            '--parallel',
            '--batch_size', "32",
            '--label_col', 'classes',
            '--n_classes', "6",
            '--normalize',
            '--dropout_rate', "0.0004",
            '--cutout_size', "94",
            '--channels', "1"
        ]

        # Remove empty arguments
        command = [arg for arg in command if arg]
        print(command)

        # Run the command
        subprocess.run(command)
# Out:
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/fixed_hp-balanced-dev-bbynd7iu.pt', '--model_type', 'dragon', '--output_path', 'tang_candidates/fixed_hp-balanced-dev-bbynd7iu', '--data_dir', 'tang_candidates', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 12:48:22,898] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 12:48:22,911] Loading images to device...
# [2024-07-22 12:48:22,951] Using 1 GPUs.
# [2024-07-22 12:48:22,954] Generating PyTorch tensors from FITS files...
# 100%|██████████| 32/32 [00:00<00:00, 2239.13it/s]
# [2024-07-22 12:48:22,970] Preloading PyTorch tensors before transfer...
# 100%|██████████| 32/32 [00:00<00:00, 1116.51it/s]
# [2024-07-22 12:48:23,084] Initialization of FITS Dataset Completed.
# [2024-07-22 12:48:23,084] Running inference run 1
# [2024-07-22 12:48:23,084] Using 1 GPUs.
# [2024-07-22 12:48:23,935] Loading model...
# [2024-07-22 12:48:23,962] Performing predictions...
# [2024-07-22 12:48:23,962] Activating Monte Carlo dropout...
# 100%|██████████| 1/1 [00:01<00:00,  1.56s/it]
# [2024-07-22 12:48:25,534] Catalog saved to tang_candidates/fixed_hp-balanced-dev-bbynd7iuinf_1.csv
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/many_models-balanced-dev-0fbt70pr.pt', '--model_type', 'dragon', '--output_path', 'tang_candidates/many_models-balanced-dev-0fbt70pr', '--data_dir', 'tang_candidates', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 12:48:27,571] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 12:48:27,583] Loading images to device...
# [2024-07-22 12:48:27,622] Using 1 GPUs.
# [2024-07-22 12:48:27,625] Generating PyTorch tensors from FITS files...
# 100%|██████████| 32/32 [00:00<00:00, 90933.42it/s]
# [2024-07-22 12:48:27,627] Preloading PyTorch tensors before transfer...
# 100%|██████████| 32/32 [00:00<00:00, 1432.33it/s]
# [2024-07-22 12:48:27,741] Initialization of FITS Dataset Completed.
# [2024-07-22 12:48:27,741] Running inference run 1
# [2024-07-22 12:48:27,741] Using 1 GPUs.
# [2024-07-22 12:48:28,582] Loading model...
# [2024-07-22 12:48:28,608] Performing predictions...
# [2024-07-22 12:48:28,609] Activating Monte Carlo dropout...
# 100%|██████████| 1/1 [00:01<00:00,  1.56s/it]
# [2024-07-22 12:48:30,179] Catalog saved to tang_candidates/many_models-balanced-dev-0fbt70prinf_1.csv
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/many_models-balanced-dev-jxvydzs2.pt', '--model_type', 'dragon', '--output_path', 'tang_candidates/many_models-balanced-dev-jxvydzs2', '--data_dir', 'tang_candidates', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 12:48:32,221] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 12:48:32,234] Loading images to device...
# [2024-07-22 12:48:32,274] Using 1 GPUs.
# [2024-07-22 12:48:32,277] Generating PyTorch tensors from FITS files...
# 100%|██████████| 32/32 [00:00<00:00, 91867.03it/s]
# [2024-07-22 12:48:32,279] Preloading PyTorch tensors before transfer...
# 100%|██████████| 32/32 [00:00<00:00, 1474.98it/s]
# [2024-07-22 12:48:32,393] Initialization of FITS Dataset Completed.
# [2024-07-22 12:48:32,393] Running inference run 1
# [2024-07-22 12:48:32,393] Using 1 GPUs.
# [2024-07-22 12:48:33,264] Loading model...
# [2024-07-22 12:48:33,290] Performing predictions...
# [2024-07-22 12:48:33,290] Activating Monte Carlo dropout...
# 100%|██████████| 1/1 [00:01<00:00,  1.57s/it]
# [2024-07-22 12:48:34,874] Catalog saved to tang_candidates/many_models-balanced-dev-jxvydzs2inf_1.csv
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/fixed_hp-balanced-dev-bbynd7iu.pt', '--model_type', 'dragon', '--output_path', 'merger_test/fixed_hp-balanced-dev-bbynd7iu', '--data_dir', 'merger_test', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 12:48:36,901] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 12:48:36,914] Loading images to device...
# [2024-07-22 12:48:36,956] Using 1 GPUs.
# [2024-07-22 12:48:36,970] Generating PyTorch tensors from FITS files...
# 100%|██████████| 12708/12708 [00:02<00:00, 4682.48it/s]
# [2024-07-22 12:48:39,686] Preloading PyTorch tensors before transfer...
# 100%|██████████| 12708/12708 [00:07<00:00, 1636.18it/s]
# [2024-07-22 12:48:47,531] Initialization of FITS Dataset Completed.
# [2024-07-22 12:48:47,531] Running inference run 1
# [2024-07-22 12:48:47,532] Using 1 GPUs.
# [2024-07-22 12:48:48,373] Loading model...
# [2024-07-22 12:48:48,399] Performing predictions...
# [2024-07-22 12:48:48,399] Activating Monte Carlo dropout...
# 100%|██████████| 398/398 [00:05<00:00, 71.17it/s]
# [2024-07-22 12:48:54,012] Catalog saved to merger_test/fixed_hp-balanced-dev-bbynd7iuinf_1.csv
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/many_models-balanced-dev-0fbt70pr.pt', '--model_type', 'dragon', '--output_path', 'merger_test/many_models-balanced-dev-0fbt70pr', '--data_dir', 'merger_test', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 12:48:56,259] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 12:48:56,272] Loading images to device...
# [2024-07-22 12:48:56,324] Using 1 GPUs.
# [2024-07-22 12:48:56,338] Generating PyTorch tensors from FITS files...
# 100%|██████████| 12708/12708 [00:00<00:00, 133433.17it/s]
# [2024-07-22 12:48:56,435] Preloading PyTorch tensors before transfer...
# 100%|██████████| 12708/12708 [00:07<00:00, 1604.21it/s]
# [2024-07-22 12:49:04,481] Initialization of FITS Dataset Completed.
# [2024-07-22 12:49:04,482] Running inference run 1
# [2024-07-22 12:49:04,482] Using 1 GPUs.
# [2024-07-22 12:49:05,330] Loading model...
# [2024-07-22 12:49:05,355] Performing predictions...
# [2024-07-22 12:49:05,355] Activating Monte Carlo dropout...
# 100%|██████████| 398/398 [00:05<00:00, 70.68it/s]
# [2024-07-22 12:49:11,008] Catalog saved to merger_test/many_models-balanced-dev-0fbt70prinf_1.csv
# ['python', 'modules/inference.py', '--model_path', 'good_models/voters/many_models-balanced-dev-jxvydzs2.pt', '--model_type', 'dragon', '--output_path', 'merger_test/many_models-balanced-dev-jxvydzs2', '--data_dir', 'merger_test', '--slug', 'balanced-dev', '--n_workers', '4', '--parallel', '--batch_size', '32', '--label_col', 'classes', '--n_classes', '6', '--normalize', '--dropout_rate', '0.0004', '--cutout_size', '94', '--channels', '1']
# [2024-07-22 12:49:13,247] Performing pure inference without labels. Using
#             column names to infer number of expected outputs.
#             Split and Slug values entered will be ignored and
#             info.csv will be used.
# [2024-07-22 12:49:13,260] Loading images to device...
# [2024-07-22 12:49:13,299] Using 1 GPUs.
# [2024-07-22 12:49:13,313] Generating PyTorch tensors from FITS files...
# 100%|██████████| 12708/12708 [00:00<00:00, 139587.52it/s]
# [2024-07-22 12:49:13,406] Preloading PyTorch tensors before transfer...
# 100%|██████████| 12708/12708 [00:07<00:00, 1641.09it/s]
# [2024-07-22 12:49:21,254] Initialization of FITS Dataset Completed.
# [2024-07-22 12:49:21,254] Running inference run 1
# [2024-07-22 12:49:21,254] Using 1 GPUs.
# [2024-07-22 12:49:22,112] Loading model...
# [2024-07-22 12:49:22,137] Performing predictions...
# [2024-07-22 12:49:22,137] Activating Monte Carlo dropout...
# 100%|██████████| 398/398 [00:05<00:00, 70.81it/s]
# [2024-07-22 12:49:27,778] Catalog saved to merger_test/many_models-balanced-dev-jxvydzs2inf_1.csv

# %%
# Creation of majority CSV
def election(output_path, data_dir):
    path = Path(data_dir)
    df = pd.DataFrame()  # Initialize an empty DataFrame
    
    index = 0
    for csv in path.glob('*inf_1.csv'):
        ndf = pd.read_csv(csv)

        # Append file names if not already present
        if "file_name" not in df.columns:
            df["file_name"] = ndf["file_name"]
        
        # Add predicted labels as new columns
        voter_column = f"voter_{index}"
        voter_confidence = f"voter_{index}_conf"
        
        df[voter_column] = ndf["predicted_labels"]
        df[voter_confidence] = ndf["predicted_confidence"]
        
        index += 1

    # Combined results
    df.to_csv(Path(output_path) / 'combined_results.csv', index=False)
    
for output_path, data_dir in zip(output_paths, data_dirs):
    election(output_path, data_dir)

# %%
def congress(path, csv='combined_results.csv'):
    df = pd.read_csv(path + '/combined_results.csv')
    congress = pd.DataFrame(columns=["file_name", "voted_class", "num_voters", "total_voters", "average_confidence", "weighted_confidence"])

    num_voters = 0
    for header in df.columns:
        if "voter" in header and not "conf" in header:
            num_voters += 1
    
    if num_voters == 0:
        return
            
    # Calculations of optimism
    labels = np.unique(df["voter_0"])   
    min_counts = {k: float('inf') for k in range(max(labels) + 1)}
    max_counts = {k: 0 for k in range(max(labels) + 1)}
    total_counts = list()
    
    for index in range(num_voters):
        counts = df[f"voter_{index}"].value_counts()
        total_counts.append(counts)
        for key in counts.index:
            min_counts[key] = min(counts[key], min_counts[key])
            max_counts[key] = max(counts[key], max_counts[key])
 
    # First round voting     
    for _, row in df.iterrows():
        voter_vals = Counter([row[f"voter_{index}"] for index in range(num_voters)])
        confidence_vals = [row[f"voter_{index}_conf"] for index in range(num_voters)]
        majority, maj_count = voter_vals.most_common(1)[0]
        
        voted_class = majority
        
        # If there is another one
        if len(voter_vals) > 1:
            second, second_count = voter_vals.most_common(2)[1]
            if maj_count - 1 <= second_count <= maj_count:
                voted_class = -1
        
        # Average confidence calculation
        avg_confidence = sum(confidence_vals) / len(confidence_vals)
        
        # Weighted voter score!
        optimisms = [total_counts[index][majority] / max_counts[majority] for index in range(num_voters)]
        weighted_probs = [confidence_vals[i] * optimisms[i] for i in range(num_voters)]
        weighted_denom = sum(optimisms)
        weighted_confidence = sum(weighted_probs) / weighted_denom
        
        congress.loc[len(congress)] = {
            "file_name": row["file_name"], 
            "voted_class": voted_class,
            "num_voters": maj_count,
            "total_voters": num_voters,
            "average_confidence": avg_confidence,
            "weighted_confidence": weighted_confidence
        }
        
    print(congress)
    congress.to_csv(path + '/congress.csv')
    
for data_dir in data_dirs:
    congress(data_dir)
# Out:
#                   file_name voted_class num_voters total_voters  \
# 0   000439.97-000146.4.fits           2          4            4
# 1   000508.37+010806.4.fits           5          4            4
# 2   000837.66-010313.7.fits           5          4            4
# 3   011935.29-002033.5.fits           2          4            4
# 4   012716.17-003557.6.fits           3          4            4
# 5   020318.87-062321.3.fits           5          4            4
# 6   021352.67-021129.4.fits           5          3            4
# 7   021930.51-055643.0.fits           4          4            4
# 8   022105.64-044101.5.fits           4          4            4
# 9   022159.71-014512.0.fits           5          4            4
# 10  084710.40-001302.6.fits           5          4            4
# 11  084856.08+011540.0.fits           5          4            4
# 12  090347.33+002026.2.fits           5          4            4
# 13  094132.90+000731.1.fits           2          3            4
# 14  121405.12+010205.1.fits           5          4            4
# 15  123821.66+010518.6.fits           5          4            4
# 16  141637.44+003352.2.fits           5          4            4
# 17  220228.65+004901.9.fits           5          4            4
# 18  220501.19+003122.8.fits           5          4            4
# 19  220718.43-001723.1.fits           5          4            4
# 20  220811.56+023830.1.fits           5          4            4
# 21  220906.91+004543.9.fits           5          4            4
# 22  221115.06-000030.9.fits           5          4            4
# 23  221227.74+005140.5.fits           5          4            4
# 24  221759.58+060426.3.fits           5          4            4
# 25  222057.44+000329.8.fits           5          4            4
# 26  222929.45+010438.4.fits           5          4            4
# 27  225147.82+001640.5.fits           5          4            4
# 28  230322.74-001438.2.fits           5          4            4
# 29  231152.90-001335.0.fits           2          3            4
# 30  232853.40+011221.8.fits           4          3            4
# 31  233713.66+005610.8.fits           5          4            4
#
#     average_confidence  weighted_confidence
# 0             0.529001             0.556676
# 1             0.974621             0.974593
# 2             0.964933             0.964680
# 3             0.742366             0.740063
# 4             0.733009             0.733009
# 5             0.983269             0.983325
# 6             0.525997             0.525682
# 7             0.795259             0.820180
# 8             0.976541             0.979258
# 9             0.625457             0.625324
# 10            0.924699             0.924586
# 11            0.954388             0.954400
# 12            0.685690             0.684186
# 13            0.499495             0.514276
# 14            0.960369             0.960348
# 15            0.843974             0.844239
# 16            0.919270             0.919009
# 17            0.963854             0.963864
# 18            0.921007             0.921340
# 19            0.545904             0.548036
# 20            0.982075             0.981988
# 21            0.946582             0.946350
# 22            0.787070             0.786178
# 23            0.948313             0.948143
# 24            0.834351             0.833356
# 25            0.937131             0.936969
# 26            0.929612             0.929891
# 27            0.849899             0.849695
# 28            0.917790             0.917502
# 29            0.756750             0.803635
# 30            0.543167             0.548267
# 31            0.971938             0.971836
#                                                file_name voted_class  \
# 0      mergerAGN_test/hsc_2626_test_HSC-G/QSO_220401_...           2
# 1      mergerAGN_test/hsc_2626_test_HSC-G/QSO_220401_...           2
# 2      mergerAGN_test/hsc_2626_test_HSC-G/QSO_220402_...           5
# 3      mergerAGN_test/hsc_2626_test_HSC-G/QSO_220402_...          -1
# 4      mergerAGN_test/hsc_2626_test_HSC-G/QSO_220402_...          -1
# ...                                                  ...         ...
# 12703  mergerAGN_test/train_data/9995-cutout-HSC-G-10...           4
# 12704  mergerAGN_test/train_data/9996-cutout-HSC-G-10...           4
# 12705  mergerAGN_test/train_data/9997-cutout-HSC-G-10...           4
# 12706  mergerAGN_test/train_data/9998-cutout-HSC-G-10...           4
# 12707  mergerAGN_test/train_data/9999-cutout-HSC-G-10...           4
#
#       num_voters total_voters  average_confidence  weighted_confidence
# 0              3            3            0.741139             0.745694
# 1              3            3            0.860240             0.862343
# 2              3            3            0.837183             0.864934
# 3              2            3            0.625558             0.856557
# 4              1            3            0.703184             0.704871
# ...          ...          ...                 ...                  ...
# 12703          3            3            0.957668             0.957573
# 12704          3            3            0.969019             0.969026
# 12705          3            3            0.936955             0.937009
# 12706          3            3            0.977867             0.977872
# 12707          3            3            0.966248             0.966256
#
# [12708 rows x 6 columns]
